# %% [markdown]
# # Лабораторна1

# %% [markdown]
# ### завдання 1

# %%
name = input("Введіть своє ім'я: ")
print(f"Hello, {name}!")
# Out:
# Hello, зщдшт!

# %% [markdown]
# ### завдання 2

# %%
import numpy as np
arr = np.random.randint(1, 101, size=10)
print("Масив випадкових чисел:", arr)
mean_value = np.mean(arr)
print("Середнє значення масиву:", mean_value)
# Out:
# Масив випадкових чисел: [76 66 25 13 78 21 16 27 96 97]
# Середнє значення масиву: 51.5

# %% [markdown]
# # Jupyter Notebook є потужним інструментом для інтерактивного програмування та аналізу даних, який дозволяє поєднувати код, текст та візуалізації в одному документі. Це особливо корисно для інтелектуального аналізу даних, де потрібно проводити експерименти, візуалізувати результати і документувати процес.
