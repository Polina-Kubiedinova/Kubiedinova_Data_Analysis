# %% [markdown]
# # Лабораторна1

# %% [markdown]
# ### завдання 1

# %%
name = input("Введіть своє ім'я: ")
print(f"Hello, {name}!")
# Out:
# Hello, polin!

# %%
import numpy as np
arr = np.random.randint(1, 101, size=10)
print("Масив випадкових чисел:", arr)
mean_value = np.mean(arr)
print("Середнє значення масиву:", mean_value)
# Out:
# Масив випадкових чисел: [68 19 22 69 99 23 87 10 59 98]
# Середнє значення масиву: 55.4
